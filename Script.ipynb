# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dist_mag = pd.read_csv('sur_spain_clasificado_web.csv')
dist_mag.head(13)
# Out:
#       0     0
# 0   0.5     0
# 1   1.0     0
# 2   1.5     0
# 3   2.0     0
# 4   2.5  2339
# 5   3.0  1950
# 6   3.5  1123
# 7   4.0   535
# 8   4.5   234
# 9   5.0    62
# 10  5.5    15
# 11  6.0     7
# 12  6.5     1

# %%
dist_mag.columns = ['magnitud', 'N']
dist_mag.head(13)
# Out:
#     magnitud     N
# 0        0.5     0
# 1        1.0     0
# 2        1.5     0
# 3        2.0     0
# 4        2.5  2339
# 5        3.0  1950
# 6        3.5  1123
# 7        4.0   535
# 8        4.5   234
# 9        5.0    62
# 10       5.5    15
# 11       6.0     7
# 12       6.5     1

# %%
magnitudes = dist_mag['magnitud']
numero = dist_mag['N']

plt.bar(x=magnitudes, height=numero, width=0.5, align='edge', edgecolor='k')
# Out:
# <BarContainer object of 19 artists>

# %%
sumatra = pd.read_csv('sumatra_2004.csv')
sumatra.head(20)
# Out:
#     Year  Month  Day      Time    Lat     Lon  Depth   Mag Region   Timestamp
# 0   2004     12   30  23:04:55  5.353  94.485   94.5  30.0     us  1104447895
# 1   2004     12   30  22:24:09  8.556  93.731   93.7  30.0     us  1104445449
# 2   2004     12   30  21:36:01  5.287  94.538   94.5  30.0     us  1104442561
# 3   2004     12   30  19:18:04  2.698  94.389   94.4  30.0     us  1104434284
# 4   2004     12   30  17:34:42  6.760  92.906   92.9  14.1     us  1104428082
# 5   2004     12   30  16:18:32  7.449  94.042   94.0  30.0     us  1104423512
# 6   2004     12   30  16:16:12  7.686  93.610   93.6  30.0     us  1104423372
# 7   2004     12   30  14:57:25  8.118  93.694   93.7  30.0     us  1104418645
# 8   2004     12   30  11:34:14  6.384  92.864   92.9  30.0     us  1104406454
# 9   2004     12   30  11:26:41  5.085  94.690   94.7  30.0     us  1104406001
# 10  2004     12   30  08:53:59  8.432  92.359   92.4  30.0     us  1104396839
# ...
